# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
total_forces = pd.read_csv('total_forces.csv', sep='\t')

# %%
print(total_forces)
# Out:
#      Unnamed: 0  physical_step  pseudo_step        CL        CD       CFx  \
# 0             0              0            0  4.983135  6.222359  4.607777
# 1             1              0           10  5.234533  5.861066  4.191186
# 2             2              0           20  4.862481  3.919942  2.427809
# 3             3              0           30  4.710815  1.334921 -0.015268
# 4             4              0           40  4.393466 -0.243866 -1.445422
# ..          ...            ...          ...       ...       ...       ...
# 296         296              0         2960  3.676447  0.077713 -0.938664
# 297         297              0         2970  3.676447  0.077713 -0.938664
# 298         298              0         2980  3.676447  0.077712 -0.938664
# 299         299              0         2990  3.676447  0.077712 -0.938664
# 300         300              0         2999  3.676447  0.077712 -0.938664
#
#           CFy       CFz       CMx       CMy  ...  CMyPressure  CMzPressure  \
# ...

# %%
print(total_forces['physical_step'])
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 296    0
# 297    0
# 298    0
# 299    0
# 300    0
# Name: physical_step, Length: 301, dtype: int64

# %%
total_forces['CL'].plot()
# Out:
# <Axes: >

# %%
total_forces['CD'].plot()
# Out:
# <Axes: >
